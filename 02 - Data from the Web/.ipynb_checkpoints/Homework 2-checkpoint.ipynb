# %%
reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from lxml import etree
import requests
from IPython.display import display, HTML

# %%
headers = {
    'x-devtools-emulate-network-conditions-client-id': "c60c3ba6-26e8-45ce-9f9f-0b5521437cf6",
    'upgrade-insecure-requests': "1",
    'user-agent': "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36",
    'accept': "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    'referer': "http://isa.epfl.ch/imoniteur_ISAP/%21gedpublicreports.htm?ww_i_reportmodel=133685247",
    'accept-encoding': "gzip, deflate, sdch",
    'accept-language': "es-ES,es;q=0.8",
    'cookie': "LANGUE_LOGIN=fr",
    'cache-control': "no-cache"
}

data = requests.get("http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.filter?ww_i_reportModel=133685247", headers=headers)

soup = BeautifulSoup(data.content, 'html.parser')
queries = soup.find_all('select')
queries_map = {}
for s in queries:
    queries_map[s.get('name')] = {}
    map = queries_map[s.get('name')]
    options = s.find_all('option')
    for o in options:
        if not o.string:
            value = ""
        else:
            value = o.string
        map[value] = o.get('value')

print(queries_map)
# Out:
# {'ww_x_UNITE_ACAD': {'': 'null', 'Mathématiques': '944590', "Sciences et ingénierie de l'environnement": '942953', 'Humanités digitales': '2054839157', 'Architecture': '942293', 'Physique': '945571', 'Chimie et génie chimique': '246696', 'Informatique': '249847', 'Cours de mathématiques spéciales': '943282', 'Section FCUE': '1574548993', 'Management de la technologie': '946882', 'EME (EPFL Middle East)': '637841336', 'Génie civil': '942623', 'Systèmes de communication': '946228', 'Génie électrique et électronique ': '943936', 'Sciences et technologies du vivant': '945901', 'Science et génie des matériaux': '944917', 'Microtechnique': '945244', 'Génie mécanique': '944263', 'Ingénierie financière': '120623110'}, 'ww_x_PERIODE_ACAD': {'': 'null', '2008-2009': '978187', '2011-2012': '123455150', '2013-2014': '213637754', '2009-2010': '978195', '2015-2016': '213638028', '2016-2017': '355925344', '2012-2013': '123456101', '2014-2015': '213637922', '2007-2008': '978181', '2010-2011': '39486325'}, 'ww_x_HIVERETE': {'': 'null', 'Semestre de printemps': '2936295', "Semestre d'automne": '2936286'}, 'ww_x_PERIODE_PEDAGO': {'': 'null', 'Bachelor semestre 1': '249108', 'Projet Master printemps': '3781783', 'Bachelor semestre 5b': '2226768', 'Bachelor semestre 4': '942163', 'Mineur semestre 2': '2335676', 'Bachelor semestre 2': '249114', 'Semestre printemps': '2754553', 'Bachelor semestre 5': '942120', 'Stage printemps master': '2227132', 'Master semestre 1': '2230106', 'Bachelor semestre 3': '942155', 'Stage printemps 4ème année': '2226626', 'Semestre automne': '953159', 'Master semestre 2': '942192', 'Stage printemps 3ème année': '983606', 'Master semestre 3': '2230128', 'Mise à niveau': '2063602308', 'Mineur semestre 1': '2335667', 'Stage automne 4ème année': '2226616', 'Bachelor semestre 6': '942175', 'Stage automne 3ème année': '953137', 'Projet Master automne': '249127', 'Bachelor semestre 6b': '2226785', 'Master semestre 4': '2230140'}}

# %%
def getData(unite_acad, periode_acad, periode_pedago, semester_type):
    unite_acad_id = queries_map['ww_x_UNITE_ACAD'][unite_acad]
    periode_acad_id = queries_map['ww_x_PERIODE_ACAD'][periode_acad]
    periode_pedago_id = queries_map['ww_x_PERIODE_PEDAGO'][periode_pedago]
    semester_type_id = queries_map['ww_x_HIVERETE'][semester_type]
    url = "http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.filter"

    querystring = {"ww_b_list":"1",
                   "ww_i_reportmodel":"133685247",
                   "ww_c_langue":"",
                   "ww_i_reportModelXsl":"133685270",
                   "zz_x_UNITE_ACAD": unite_acad,
                   "ww_x_UNITE_ACAD": unite_acad_id,
                   "zz_x_PERIODE_ACAD": periode_acad,
                   "ww_x_PERIODE_ACAD":periode_acad_id,
                   "zz_x_PERIODE_PEDAGO":periode_pedago,
                   "ww_x_PERIODE_PEDAGO":periode_pedago_id,
                   "zz_x_HIVERETE":semester_type,
                   "ww_x_HIVERETE":semester_type_id,
                   "dummy":"ok"}

    headers = {
        'upgrade-insecure-requests': "1",
        'user-agent': "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36",
        'accept': "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
        'referer': "http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.filter?ww_i_reportModel=133685247",
        'accept-encoding': "gzip, deflate, sdch",
        'accept-language': "es-ES,es;q=0.8",
        'cookie': "LANGUE_LOGIN=fr",
        'cache-control': "no-cache",
        'postman-token': "65d96955-59bb-daa2-5136-807135f5b89a"
        }

    text = BeautifulSoup(requests.request("GET", url, headers=headers, params=querystring).text, 'html.parser')
    if (len(text.find_all('table')[2].find_all('tr')) != 0):
        gps = list(text.find_all('table'))[2].find_all('tr')[1].td.a.get('onclick').split('ww_x_GPS=')[1].split("')")[0]
        payload = {'ww_x_GPS': int(gps),
                   'ww_i_reportModel':133685247, 
                   'ww_i_reportModelXsl': 133685271,
                   'ww_x_UNITE_ACAD': unite_acad_id,
                   'ww_x_PERIODE_ACAD': periode_acad_id,
                   'ww_x_PERIODE_PEDAGO': periode_pedago_id,
                   'ww_x_HIVERETE': semester_type_id
                  }
        r = requests.get("http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.XLS", params=payload)
        return r.text
    else:
        return ''

# %%
df_final = None
df_year = None

def addData(unite_acad, periode_acad, periode_pedago, semester_type, list_semesters):

    unite_acad_id = queries_map['ww_x_UNITE_ACAD'][unite_acad]
    periode_acad_id = queries_map['ww_x_PERIODE_ACAD'][periode_acad]
    periode_pedago_id = queries_map['ww_x_PERIODE_PEDAGO'][periode_pedago]
    semester_type_id = queries_map['ww_x_HIVERETE'][semester_type]

    text_to_soup = getData(unite_acad,periode_acad,periode_pedago,semester_type)
    if text_to_soup == '':
        return None
    
    soup = BeautifulSoup(text_to_soup, 'html.parser')
    rows = soup.find_all('tr')
    if len(rows) < 3:
        return None
    header_cols = rows[2].find_all('th')
    col_titles, data = [], {}
    
    for c in header_cols:
        data[c.string] = []
        col_titles.append(c.string)
    [col_titles.append(semestre.split(' ')[1] + ' ' + semestre.split(' ')[2]) for semestre in list_semesters]

    for semestre in list_semesters:
        data[semestre.split(' ')[1] + ' ' + semestre.split(' ')[2]] = [ float('nan') ] * ( len(rows) - 3)
    col_titles.append('enter')
    data['enter'] = None
    col_titles.append('exit')
    data['exit'] = None
    global df_final, df_year


    df = pd.DataFrame(columns=col_titles)
    df.set_index(['No Sciper'], inplace=True, drop=False)
    if df_final is None:
        df_final = df.copy()
    if df_year is None:
        df_year = df.copy() 

    for h in range(3, len(rows)):
        values = rows[h].find_all('td')
        for v in range(len(values)-2):
            data[header_cols[v].string].append(values[v].string)
        data[periode_pedago.split(' ')[1] + ' ' + periode_pedago.split(' ')[2]][h-3] =  True 
    df = pd.DataFrame.from_dict(data)
    df.set_index(['No Sciper'], inplace=True, drop=False)
    return df

# %%
def combineDataYear(new_data, old_data, semestre, year):
    print(semestre, year)
    semestre_name = semestre.split(' ')[1] + ' ' + semestre.split(' ')[2]
    for user in new_data['No Sciper'].tolist():
        if (user in old_data['No Sciper'].tolist()):
            #print(old_data[semestre[9:]].loc[old_data['No Sciper'] == user], "*******")
            old_data[semestre_name].loc[old_data['No Sciper'] == user] = True
            old_data['exit'].loc[old_data['No Sciper'] == user] = year
        else:
            new_data['enter'].loc[new_data['No Sciper'] == user] = year
            new_data['exit'].loc[new_data['No Sciper'] == user] = year
            old_data = pd.concat([old_data, new_data.loc[new_data['No Sciper'] == user]], ignore_index=True)
            #print(new_data['semestre 1'].loc[new_data['No Sciper'] == user])
    old_data.set_index(['No Sciper'], inplace=True, drop=False)


    return old_data

def combineDataTotal(new_data, old_data):
    old_data = old_data.combine_first(new_data)
    for user in new_data['No Sciper'].tolist():
        #if user in old_data['No Sciper'].tolist():
        #    old_data.loc[old_data['No Sciper'] == user] = old_data.loc[old_data['No Sciper'] == user].combine_first(new_data.loc[new_data['No Sciper'] == user])
            
            
            #old_data.update(new_data, overwrite=True)
        #else:
        if user not in old_data['No Sciper'].tolist():
            old_data = pd.concat([old_data, new_data.loc[new_data['No Sciper'] == user]])
        else:
            old_data['exit'].loc[old_data['No Sciper'] == user] = new_data['exit'].loc[new_data['No Sciper'] == user]
    old_data.set_index(['No Sciper'], inplace=True, drop=False)

    return old_data

# %%
unite_acad = "Informatique"
periode_acad = list(queries_map['ww_x_PERIODE_ACAD'].keys())
periode_acad.remove('')
periode_pedago = []
for p in list(queries_map['ww_x_PERIODE_PEDAGO'].keys()):
    if 'Bachelor' in p and "b" not in p:
        periode_pedago.append(p)
periode_pedago = sorted(periode_pedago)
periode_acad = sorted(periode_acad)
df_final = None
df_year = None


for year in range(len(periode_acad)):
    df_year = None
    for s in range(len(periode_pedago)):
        a = addData("Informatique", periode_acad[year], periode_pedago[s], "", periode_pedago)
        if a is None:
            continue
        df_year = combineDataYear(a, df_year, periode_pedago[s], periode_acad[year])
        #display(df_year)
    df_final = combineDataTotal(df_year, df_final)
    
display(df_final)
# Out:
# Bachelor semestre 1 2007-2008
# /Users/nachoaguadoc/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 161814     Monsieur                                    NaN          NaN
# 161930     Monsieur                                    NaN          NaN
# 165562     Monsieur                                    NaN          NaN
# 166001     Monsieur                                    NaN          NaN
# 166260     Monsieur                                    NaN          NaN
# 166344     Monsieur                                    NaN          NaN
# 166548     Monsieur                    University of Tokyo          NaN
# 166701     Monsieur                                    NaN          NaN
# 166746     Monsieur                                    NaN          NaN
# 166748     Monsieur                                    NaN          NaN
# 166751     Monsieur                                    NaN          NaN
# 166889     Monsieur                                    NaN          NaN
# 167007     Monsieur                                    NaN          NaN
# 167045     Monsieur                                    NaN          NaN
# 167313     Monsieur                                    NaN          NaN
# 167386     Monsieur                                    NaN          NaN
# 167439     Monsieur                                    NaN          NaN
# 167447     Monsieur                                    NaN          NaN
# ...             ...                                    ...          ...
# 274740     Monsieur                                   None         None
# 274746     Monsieur                                   None         None
# 274748     Monsieur                                   None         None
# 274751       Madame                                   None         None
# 274839       Madame                                   None         None
# 274900     Monsieur                                   None         None
# 274902       Madame                                   None         None
# 274918     Monsieur                                   None         None
# 274944     Monsieur                                   None         None
# 274957       Madame                                   None         None
# 274960     Monsieur                                   None         None
# 274999     Monsieur                                   None         None
# 275001       Madame                                   None         None
# 275071     Monsieur                                   None         None
# 275102     Monsieur                                   None         None
# 275105     Monsieur                                   None         None
# 275116     Monsieur                                   None         None
# 275142     Monsieur                                   None         None
# 275159     Monsieur                                   None         None
# 275199     Monsieur                                   None         None
# 275273     Monsieur                                   None         None
# 275313     Monsieur                                   None         None
# 275383     Monsieur                                   None         None
# 275553     Monsieur                                   None         None
# 275608     Monsieur                                   None         None
# 276016     Monsieur                                   None         None
# 276323     Monsieur                                   None         None
# 276507     Monsieur                                   None         None
# 276937     Monsieur                                   None         None
# 277113     Monsieur                                   None         None
#
#            Mineur No Sciper  \
# No Sciper
# 147008        NaN    147008
# 153762        NaN    153762
# 154157        NaN    154157
# 159516        NaN    159516
# 159998        NaN    159998
# 160213        NaN    160213
# 161091        NaN    161091
# 161127        NaN    161127
# 161212        NaN    161212
# 161220        NaN    161220
# 161279        NaN    161279
# 161634        NaN    161634
# 161814        NaN    161814
# 161930        NaN    161930
# 165562        NaN    165562
# 166001        NaN    166001
# 166260        NaN    166260
# 166344        NaN    166344
# 166548        NaN    166548
# 166701        NaN    166701
# 166746        NaN    166746
# 166748        NaN    166748
# 166751        NaN    166751
# 166889        NaN    166889
# 167007        NaN    167007
# 167045        NaN    167045
# 167313        NaN    167313
# 167386        NaN    167386
# 167439        NaN    167439
# 167447        NaN    167447
# ...           ...       ...
# 274740        NaN    274740
# 274746        NaN    274746
# 274748        NaN    274748
# 274751        NaN    274751
# 274839        NaN    274839
# 274900        NaN    274900
# 274902        NaN    274902
# 274918        NaN    274918
# 274944        NaN    274944
# 274957        NaN    274957
# 274960        NaN    274960
# 274999        NaN    274999
# 275001        NaN    275001
# 275071        NaN    275071
# 275102        NaN    275102
# 275105        NaN    275105
# 275116        NaN    275116
# 275142        NaN    275142
# 276016            None  2016-2017  2016-2017       True        NaN        NaN
# 276323            None  2016-2017  2016-2017       True        NaN        NaN
# 276507            None  2016-2017  2016-2017       True        NaN        NaN
# 276937            None  2016-2017  2016-2017       True        NaN        NaN
# 277113            None  2016-2017  2016-2017       True        NaN        NaN
#
#           semestre 4 semestre 5 semestre 6
# No Sciper
# 147008          True       True       True
# 153762           NaN       True       True
# 154157           NaN       True        NaN
# 159516           NaN       True       True
# 159998           NaN       True       True
# 160213           NaN       True        NaN
# 161091           NaN       True       True
# 161127           NaN       True       True
# 161212           NaN        NaN        NaN
# 161220           NaN       True       True
# 161279           NaN       True       True
# 161634           NaN       True       True
# 161814           NaN       True       True
# 161930          True       True       True
# 165562           NaN       True       True
# 166001           NaN       True        NaN
# 166260           NaN       True       True
# 166344           NaN       True       True
# 166548           NaN       True       True
# 166701           NaN       True       True
# 166746           NaN       True       True
# 166748           NaN       True       True
# 166751           NaN       True       True
# 166889           NaN       True       True
# 167007           NaN       True       True
# 167045           NaN       True       True
# 167313           NaN       True       True
# 167386           NaN       True       True
# 167439           NaN       True       True
# 167447           NaN       True        NaN
# ...              ...        ...        ...
# 274740           NaN        NaN        NaN
# 274746           NaN        NaN        NaN
# 274748           NaN        NaN        NaN
# 274751           NaN        NaN        NaN
# 274839           NaN        NaN        NaN
# 274900           NaN        NaN        NaN
# 274902           NaN        NaN        NaN
# 274918           NaN        NaN        NaN
# 274944           NaN        NaN        NaN
# 274957           NaN        NaN        NaN
# 274960           NaN        NaN        NaN
# 274999           NaN        NaN        NaN
# 275001           NaN        NaN        NaN
# 275071           NaN        NaN        NaN
# 275102           NaN        NaN        NaN
# 275105           NaN        NaN        NaN
# 275116           NaN        NaN        NaN
# 275142           NaN        NaN        NaN
# 275159           NaN        NaN        NaN
# 275199           NaN        NaN        NaN
# 275273           NaN        NaN        NaN
# 275313           NaN        NaN        NaN
# 275383           NaN        NaN        NaN
# 275553           NaN        NaN        NaN
# 275608           NaN        NaN        NaN
# 276016           NaN        NaN        NaN
# 276323           NaN        NaN        NaN
# 276507           NaN        NaN        NaN
# 276937           NaN        NaN        NaN
# 277113           NaN        NaN        NaN
#
# [1477 rows x 19 columns]

# %% [markdown]
# hola

# %%
df_final.drop(['Ecole Echange', 'Filičre opt.', 'Mineur', 'Orientation Bachelor','Orientation Master', 'Spécialisation', 'Type Echange' ],1)
# Out:
#            Civilité No Sciper  \
# No Sciper
# 147008     Monsieur    147008
# 153762     Monsieur    153762
# 154157       Madame    154157
# 159516     Monsieur    159516
# 159998       Madame    159998
# 160213     Monsieur    160213
# 161091       Madame    161091
# 161127     Monsieur    161127
# 161212     Monsieur    161212
# 161220     Monsieur    161220
# 161279     Monsieur    161279
# 161634     Monsieur    161634
# 161814     Monsieur    161814
# 161930     Monsieur    161930
# 165562     Monsieur    165562
# 166001     Monsieur    166001
# 166260     Monsieur    166260
# 166344     Monsieur    166344
# 166548     Monsieur    166548
# 166701     Monsieur    166701
# 275001                                         Idrizi Gonxhe  Présent
# 275071                                          Krcmar Peter  Présent
# 275102                                      Friedli Jonathan  Présent
# 275105                                Fournier Julien Marcel  Présent
# 275116                                        Fusi Noah Duoc  Présent
# 275142                                Luisier Gabriel Xavier  Présent
# 275159                              Nejad Sattary Kamran Ali  Présent
# 275199                       Ottaviani Lorenzo Antonio Maria  Présent
# 275273                              Servat Jean-Marc Patrick  Présent
# 275313                                   Dumoulin Paul Milan  Présent
# 275383                                  Cochard Victor Angel  Présent
# 275553                                             Hu Julien  Présent
# 275608                                             Boujo Max  Présent
# 276016                               Wilders Eric Bruno John  Présent
# 276323                            Zeller Corentin Luc Claude  Présent
# 276507     Thierry D'Argenlieu Nicolas Alain Alexandre Marie  Présent
# 276937                         Chappuis Sébastien Max Roland  Présent
# 277113                                        Geinoz Grégory  Présent
#
#                enter       exit semestre 1 semestre 2 semestre 3 semestre 4  \
# No Sciper
# 147008     2008-2009  2010-2011       True       True       True       True
# 153762     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 154157     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 159516     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 159998     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 160213     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 161091     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 161127     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 161212     2009-2010  2009-2010       True       True        NaN        NaN
# 161220     2007-2008  2008-2009        NaN        NaN        NaN        NaN
# 161279     2007-2008  2008-2009        NaN        NaN        NaN        NaN
# 161634     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 161814     2007-2008  2008-2009        NaN        NaN        NaN        NaN
# 161930     2007-2008  2009-2010        NaN        NaN       True       True
# 165562     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 166001     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 166260     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 166344     2007-2008  2008-2009        NaN        NaN        NaN        NaN
# 166548     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 166701     2007-2008  2008-2009        NaN        NaN        NaN        NaN
# 166746     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 166748     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 166751     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 166889     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 167007     2007-2008  2009-2010        NaN        NaN        NaN        NaN
# 167045     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 167313     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 167386     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 167439     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# 167447     2007-2008  2007-2008        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 274740     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274746     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274748     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274751     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274839     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274900     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274902     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274918     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274944     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274957     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274960     2016-2017  2016-2017       True        NaN        NaN        NaN
# 274999     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275001     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275071     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275102     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275105     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275116     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275142     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275159     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275199     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275273     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275313     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275383     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275553     2016-2017  2016-2017       True        NaN        NaN        NaN
# 275608     2016-2017  2016-2017       True        NaN        NaN        NaN
# 276016     2016-2017  2016-2017       True        NaN        NaN        NaN
# 276323     2016-2017  2016-2017       True        NaN        NaN        NaN
# 276507     2016-2017  2016-2017       True        NaN        NaN        NaN
# 276937     2016-2017  2016-2017       True        NaN        NaN        NaN
# 277113     2016-2017  2016-2017       True        NaN        NaN        NaN
#
#           semestre 5 semestre 6
# No Sciper
# 147008          True       True
# 153762          True       True
# 154157          True        NaN
# 159516          True       True
# 159998          True       True
# 160213          True        NaN
# 161091          True       True
# 161127          True       True
# 161212           NaN        NaN
# 161220          True       True
# 161279          True       True
# 161634          True       True
# 161814          True       True
# 161930          True       True
# 165562          True       True
# 166001          True        NaN
# 166260          True       True
# 166344          True       True
# 166548          True       True
# 166701          True       True
# 166746          True       True
# 166748          True       True
# 166751          True       True
# 166889          True       True
# 167007          True       True
# 167045          True       True
# 167313          True       True
# 167386          True       True
# 167439          True       True
# 167447          True        NaN
# ...              ...        ...
# 274740           NaN        NaN
# 274746           NaN        NaN
# 274748           NaN        NaN
# 274751           NaN        NaN
# 274839           NaN        NaN
# 274900           NaN        NaN
# 274902           NaN        NaN
# 274918           NaN        NaN
# 274944           NaN        NaN
# 274957           NaN        NaN
# 274960           NaN        NaN
# 274999           NaN        NaN
# 275001           NaN        NaN
# 275071           NaN        NaN
# 275102           NaN        NaN
# 275105           NaN        NaN
# 275116           NaN        NaN
# 275142           NaN        NaN
# 275159           NaN        NaN
# 275199           NaN        NaN
# 275273           NaN        NaN
# 275313           NaN        NaN
# 275383           NaN        NaN
# 275553           NaN        NaN
# 275608           NaN        NaN
# 276016           NaN        NaN
# 276323           NaN        NaN
# 276507           NaN        NaN
# 276937           NaN        NaN
# 277113           NaN        NaN
#
# [1477 rows x 12 columns]

# %% [markdown]
# Now....

# %%
df_final_sm1 = df_final[df_final['semestre 1'] == True]
df_final = df_final_sm1[df_final_sm1['semestre 6'] == True]
num_total = len(df_final)

# %%
num_women = len(df_final[df_final['Civilité'] == 'Madame'])

# %%
from pylab import *

# make a square figure and axes
figure(1, figsize=(6,6))
ax = axes([0.1, 0.1, 0.8, 0.8])

# The slices will be ordered and plotted counter-clockwise.
labels = 'Men', 'Women'
fracs = [num_total-num_women, num_women]
explode=(0, 0.5)

pie(fracs, explode=explode, labels=labels,
                autopct='%1.1f%%', shadow=True, startangle=90)

title('Men and Women in CS', bbox={'facecolor':'0.8', 'pad':5})

show()

# %%
init_dates = df_final[['enter', 'exit']].as_matrix()
durations = []
for i in init_dates:
    init = int(i[0].split('-')[0])
    final = int(i[1].split('-')[1])
    months = (final - init)*12 - 3
    durations.append(months)
sum(durations)/len(durations)
# Out:
# 40.8287153652393

# %% [markdown]
# # EXERCISE 2
# Perform a similar operation to what described above, this time for Master students. Notice that this data is more tricky, as there are many missing records in the IS-Academia database. Therefore, try to guess how much time a master student spent at EPFL by at least checking the distance in months between `Master semestre 1` and `Master semestre 2`. If the `Mineur` field is *not* empty, the student should also appear registered in `Master semestre 3`. Last but not the least, don't forget to check if the student has an entry also in the `Projet Master` tables. Once you can handle well this data, compute the "average stay at EPFL" for master students. Now extract all the students with a `Spécialisation` and compute the "average stay" per each category of that attribute -- compared to the general average, can you find any specialization for which the difference in average is statistically significant?

# %%
unite_acad = "Informatique"
periode_acad = list(queries_map['ww_x_PERIODE_ACAD'].keys())
periode_acad.remove('')
periode_pedago = []
for p in list(queries_map['ww_x_PERIODE_PEDAGO'].keys()):
    if 'Master' in p:
        periode_pedago.append(p)

        periode_pedago = sorted(periode_pedago)
periode_acad = sorted(periode_acad)
df_final = None
df_year = None


for year in range(len(periode_acad)):
    df_year = None
    for s in range(len(periode_pedago)):
        a = addData("Informatique", periode_acad[year], periode_pedago[s], "", periode_pedago)
        if a is None:
            continue
        df_year = combineDataYear(a, df_year, periode_pedago[s], periode_acad[year])
        #display(df_year)
    df_final= combineDataTotal(df_year, df_final)

df_final_master = df_final.copy()
display(df_final_master)
# Out:
# Master semestre 1 2007-2008
# /Users/nachoaguadoc/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Master semestre 2 2007-2008
# Master semestre 3 2007-2008
# Projet Master automne 2007-2008
# Projet Master printemps 2007-2008
# Master semestre 1 2008-2009
# Master semestre 2 2008-2009
# Master semestre 3 2008-2009
# Projet Master automne 2008-2009
# Projet Master printemps 2008-2009
# Master semestre 1 2009-2010
# Master semestre 2 2009-2010
# Master semestre 3 2009-2010
# Projet Master automne 2009-2010
# Projet Master printemps 2009-2010
# Master semestre 1 2010-2011
# Master semestre 2 2010-2011
# Master semestre 3 2010-2011
# Projet Master automne 2010-2011
# Projet Master printemps 2010-2011
# Master semestre 1 2011-2012
# Master semestre 2 2011-2012
# Master semestre 3 2011-2012
# Projet Master automne 2011-2012
# Projet Master printemps 2011-2012
# Master semestre 1 2012-2013
# Master semestre 2 2012-2013
# Master semestre 3 2012-2013
# Projet Master automne 2012-2013
# Projet Master printemps 2012-2013
# Master semestre 1 2013-2014
# Master semestre 2 2013-2014
# Master semestre 3 2013-2014
# Projet Master automne 2013-2014
# Projet Master printemps 2013-2014
# Master semestre 1 2014-2015
# Master semestre 2 2014-2015
# Master semestre 3 2014-2015
# Projet Master automne 2014-2015
# Master semestre 1 2015-2016
# Master semestre 2 2015-2016
# Master semestre 3 2015-2016
# Projet Master automne 2015-2016
# Master semestre 1 2016-2017
# Master semestre 2 2016-2017
# Master semestre 3 2016-2017
# Projet Master automne 2016-2017
#            Civilité Ecole Echange  Filičre opt. Master automne  \
# No Sciper
# 128911     Monsieur           NaN           NaN            NaN
# 129093     Monsieur           NaN           NaN            NaN
# 129326     Monsieur           NaN           NaN            NaN
# 138088     Monsieur           NaN           NaN            NaN
# 145546     Monsieur           NaN           NaN            NaN
# 145957     Monsieur           NaN           NaN            NaN
# 146330     Monsieur           NaN           NaN            NaN
# 146441       Madame           NaN           NaN            NaN
# 146742     Monsieur           NaN           NaN           True
# 146752     Monsieur           NaN           NaN            NaN
# 146929     Monsieur           NaN           NaN            NaN
# 147008     Monsieur           NaN           NaN            NaN
# 147358     Monsieur           NaN           NaN            NaN
# 147362     Monsieur           NaN           NaN            NaN
# 147366     Monsieur           NaN           NaN            NaN
# 147445     Monsieur           NaN           NaN            NaN
# 148900     Monsieur           NaN           NaN            NaN
# 152232     Monsieur           NaN           NaN            NaN
# 152238     Monsieur           NaN           NaN            NaN
# 153066     Monsieur           NaN           NaN            NaN
# 153324     Monsieur           NaN           NaN            NaN
# 153506       Madame           NaN           NaN            NaN
# 153640     Monsieur           NaN           NaN            NaN
# 153641     Monsieur           NaN           NaN            NaN
# 153642     Monsieur           NaN           NaN            NaN
# 153645     Monsieur           NaN           NaN            NaN
# 153664     Monsieur           NaN           NaN            NaN
# 153742     Monsieur           NaN           NaN            NaN
# 153746     Monsieur           NaN           NaN            NaN
# 153762     Monsieur           NaN           NaN            NaN
# ...             ...           ...           ...            ...
# 268907     Monsieur          None           NaN            NaN
# 268910     Monsieur          None           NaN            NaN
# 269057       Madame          None           NaN            NaN
# 269096     Monsieur          None           NaN            NaN
# 269098     Monsieur          None           NaN            NaN
# 269369     Monsieur          None           NaN            NaN
# 269412     Monsieur          None           NaN            NaN
# 269423       Madame          None           NaN            NaN
# 269467     Monsieur          None           NaN            NaN
# 271189     Monsieur          None           NaN            NaN
# 271331     Monsieur          None           NaN            NaN
# 271711     Monsieur          None           NaN            NaN
# 271965     Monsieur          None           NaN            NaN
# 272025       Madame          None           NaN            NaN
# 272086       Madame          None           NaN            NaN
# 272324     Monsieur          None           NaN            NaN
# 272509     Monsieur          None           NaN            NaN
# 272620     Monsieur          None           NaN            NaN
# 272783     Monsieur          None           NaN            NaN
# 272785     Monsieur          None           NaN            NaN
# 272817       Madame          None           NaN            NaN
# 273006       Madame          None           NaN            NaN
# 273101     Monsieur          None           NaN            NaN
# 273107     Monsieur          None           NaN            NaN
# 273118     Monsieur          None           NaN            NaN
# 273156     Monsieur          None           NaN            NaN
# 273163     Monsieur          None           NaN            NaN
# 273182     Monsieur          None           NaN            NaN
# 273251     Monsieur          None           NaN            NaN
# 273563       Madame          None           NaN            NaN
#
#           Master printemps                                             Mineur  \
# No Sciper
# 128911                 NaN                                                NaN
# 129093                 NaN                                                NaN
# 129326                 NaN                                                NaN
# 138088                 NaN                                                NaN
# 145546                 NaN                                                NaN
# 145957                True                                                NaN
# 146330                 NaN                                                NaN
# 146441                 NaN                                                NaN
# 146742                True                                                NaN
# 146752                 NaN                                                NaN
# 146929                 NaN                                                NaN
# 147008                 NaN                                                NaN
# 147358                 NaN                                                NaN
# 147362                 NaN                                                NaN
# 147366                 NaN                                                NaN
# 147445                 NaN                                                NaN
# 148900                 NaN                                                NaN
# 152232                 NaN  Mineur en Management, technologie et entrepren...
# 152238                 NaN                                                NaN
# 153066                 NaN                                                NaN
# 153324                 NaN                                                NaN
# 153506                 NaN                                                NaN
# 153640                 NaN                                                NaN
# 153641                 NaN                                                NaN
# 153642                 NaN  Mineur en Management, technologie et entrepren...
# 153645                 NaN  Mineur en Management, technologie et entrepren...
# 153664                 NaN                                                NaN
# 153742                 NaN                                                NaN
# 153746                 NaN                                                NaN
# 153762                 NaN                                                NaN
# ...                    ...                                                ...
# 268907                 NaN                                               None
# 268910                 NaN                                               None
# 269057                 NaN                                               None
# 269096                 NaN                                               None
# 269098                 NaN                                               None
# 269369                 NaN                                               None
# 269412                 NaN                                               None
# 269423                 NaN                                               None
# 269467                 NaN                                               None
# 271189                 NaN                                               None
# 271331                 NaN                                               None
# 271711                 NaN                                               None
# 271965                 NaN                                               None
# 272025                 NaN                                               None
# 272086                 NaN                                               None
# 272324                 NaN                                               None
# 272509                 NaN                                               None
# 272620                 NaN                                               None
# 272783                 NaN                                               None
# 272785                 NaN                                               None
# 272817                 NaN                                               None
# 273006                 NaN                                               None
# 273101                 NaN                                               None
# 273107                 NaN                                               None
# 273118                 NaN                                               None
# 273156                 NaN                                               None
# 273163                 NaN                                               None
# 273182                 NaN                                               None
# 273251                 NaN                                               None
# 273563                 NaN                                               None
#
#           No Sciper                                         Nom Prénom  \
# No Sciper
# 128911       128911                                     Gulati Asheesh
# 129093       129093                                         Zhou Maoan
# 129326       129326                                     Ni Zhong Zhong
# 138088       138088                            Droz-dit-Busset Arnault
# 145546       145546                               Clivaz Jean-Philippe
# 145957       145957                                      Hügli Michael
# 146330       146330                                   Cardinaux Damien
# 146441       146441                                   Henriot Laetitia
# 146742       146742                                       Marx Clément
# 146752       146752                                   De Lamarter Erik
# 146929       146929                                      Junod Antoine
# 147008       147008                                        Good Xavier
# 147358       147358                                    Conus Christian
# 147362       147362                               Rey Charles François
# 147366       147366                                  Schönmann Patrick
# 147445       147445                                Robert Pierre-Alain
# 148900       148900                               Nansi Fabrice Cédric
# 152232       152232                                 Anagnostaras David
# 152238       152238                                   Tagliani Raphaël
# 153066       153066                          Aeberhard François-Xavier
# 153324       153324                                    Cantale Nicolas
# 153506       153506                            Hanser Cyrielle Morgane
# 153640       153640                          Matthey-de-l'Endroit Loďc
# 153641       153641                                       Favre Cédric
# 153642       153642                                      Imhoff Lionel
# 153645       153645                                       Rosat Damien
# 153664       153664                                 Brandinu Guillaume
# 153742       153742                                      Bozzo Vincent
# 153746       153746                                       Cassina Ilya
# 153762       153762                                       Conus Johann
# ...             ...                                                ...
# 268907       268907                                    Dimovski Mladen
# 268910       268910                                   Hendrikx Hadrien
# 269057       269057                                        Zhang Weiyu
# 269096       269096                              Tomoiaga Ciprian-Ioan
# 269098       269098                                      Petri Vincent
# 269369       269369                                 Bhattacharyya Atri
# 269412       269412                                       Kjosev Tasho
# 269423       269423                                      Najdenova Iva
# 269467       269467                                   Shevchenko Artem
# 271189       271189                                   Tresch Christian
# 271331       271331                                   Adams Marc Alain
# 271711       271711                                  Martinelli Mattia
# 271965       271965                         Holloway Alexander Patrick
# 272025       272025                                     El Zein Yamane
# 272086       272086                                         Nie Shiyue
# 272324       272324                         Colombo Pierre Jean Adrien
# 272509       272509                                     Sacchi Niccolň
# 272620       272620                            Gotmare Akhilesh Deepak
# 272783       272783                      Launay Clément Hervé Stéphane
# 272785       272785  Le Tourneux De La Perraudiere Valentin Marie Marc
# 272817       272817                                Kuziora Marta Kinga
# 273006       273006                                          Yin Wensi
# 273101       273101                                    Adamsons Valdis
# 273107       273107                        Aquil Mohammad Amimul Ihsan
# 273118       273118                                   Barbera Antonino
# 273156       273156                     Champenois Bertrand Brice Marc
# 273163       273163                         del Marmol Syméon Marie J.
# 273182       273182                                   Vasiliu Valentin
# 273251       273251                                       Pavllo Dario
# 273563       273563                                        Yiue Ya-Lan
#
#            Orientation Bachelor  Orientation Master  \
# No Sciper
# 128911                      NaN                 NaN
# 129093                      NaN                 NaN
# 129326                      NaN                 NaN
# 138088                      NaN                 NaN
# 145546                      NaN                 NaN
# 145957                      NaN                 NaN
# 146330                      NaN                 NaN
# 146441                      NaN                 NaN
# 146742                      NaN                 NaN
# 146752                      NaN                 NaN
# 146929                      NaN                 NaN
# 147008                      NaN                 NaN
# 147358                      NaN                 NaN
# 147362                      NaN                 NaN
# 147366                      NaN                 NaN
# 147445                      NaN                 NaN
# 148900                      NaN                 NaN
# 152232                      NaN                 NaN
# 152238                      NaN                 NaN
# 153066                      NaN                 NaN
# 153324                      NaN                 NaN
# 153506                      NaN                 NaN
# 153640                      NaN                 NaN
# 153641                      NaN                 NaN
# 153642                      NaN                 NaN
# 153645                      NaN                 NaN
# 153664                      NaN                 NaN
# 153742                      NaN                 NaN
# 153746                      NaN                 NaN
# 153762                      NaN                 NaN
# ...                         ...                 ...
# 268907                      NaN                 NaN
# 268910                      NaN                 NaN
# 269057                      NaN                 NaN
# 269096                      NaN                 NaN
# 269098                      NaN                 NaN
# 269369                      NaN                 NaN
# 269412                      NaN                 NaN
# 269423                      NaN                 NaN
# 269467                      NaN                 NaN
# 271189                      NaN                 NaN
# 271331                      NaN                 NaN
# 271711                      NaN                 NaN
# 271965                      NaN                 NaN
# 272025                      NaN                 NaN
# 272086                      NaN                 NaN
# 272324                      NaN                 NaN
# 272509                      NaN                 NaN
# 272620                      NaN                 NaN
# 272783                      NaN                 NaN
# 272785                      NaN                 NaN
# 272817                      NaN                 NaN
# 273006                      NaN                 NaN
# 273101                      NaN                 NaN
# 273107                      NaN                 NaN
# 273118                      NaN                 NaN
# 273156                      NaN                 NaN
# 273163                      NaN                 NaN
# 273182                      NaN                 NaN
# 273251                      NaN                 NaN
# 273563                      NaN                 NaN
#
#                            Spécialisation   Statut Type Echange      enter  \
# No Sciper
# 128911                 Internet computing  Présent          NaN  2007-2008
# 129093                                NaN  Présent          NaN  2007-2008
# 129326                                NaN  Présent          NaN  2007-2008
# 138088                                NaN  Présent          NaN  2007-2008
# 145546                                NaN  Présent          NaN  2007-2008
# 145957                                NaN  Présent          NaN  2007-2008
# 146330                                NaN  Présent          NaN  2007-2008
# 146441                                NaN  Présent          NaN  2007-2008
# 146742     Signals, Images and Interfaces  Présent          NaN  2008-2009
# 146752                                NaN  Présent          NaN  2007-2008
# 146929                                NaN  Présent          NaN  2007-2008
# 147008     Signals, Images and Interfaces  Présent          NaN  2011-2012
# 147358                                NaN  Présent          NaN  2007-2008
# 147362                                NaN  Présent          NaN  2007-2008
# 147366                                NaN  Présent          NaN  2007-2008
# 147445                                NaN  Présent          NaN  2007-2008
# 148900                                NaN  Présent          NaN  2007-2008
# 152232                                NaN  Présent          NaN  2007-2008
# 152238                 Internet computing  Présent          NaN  2007-2008
# 153066                 Internet computing  Présent          NaN  2007-2008
# 153324                                NaN  Présent          NaN  2007-2008
# 153506                                NaN  Présent          NaN  2007-2008
# 153640                       Biocomputing  Présent          NaN  2007-2008
# 153641                 Internet computing  Présent          NaN  2007-2008
# 153642                                NaN  Présent          NaN  2007-2008
# 153645                                NaN  Présent          NaN  2007-2008
# 153664     Signals, Images and Interfaces  Présent          NaN  2007-2008
# 153742     Signals, Images and Interfaces  Présent          NaN  2007-2008
# 153746                                NaN  Présent          NaN  2007-2008
# 153762                                NaN  Présent          NaN  2008-2009
# ...                                   ...      ...          ...        ...
# 268907                               None  Présent         None  2016-2017
# 268910                               None  Présent         None  2016-2017
# 269057                               None  Présent         None  2016-2017
# 269096                     Data Analytics  Présent         None  2016-2017
# 269098                               None  Présent         None  2016-2017
# 269369                               None  Présent         None  2016-2017
# 269412                               None  Présent         None  2016-2017
# 269423                               None  Présent         None  2016-2017
# 269467                               None  Présent         None  2016-2017
# 271189                               None  Présent         None  2016-2017
# 271331                               None  Présent         None  2016-2017
# 271711                               None  Présent         None  2016-2017
# 271965                               None  Présent         None  2016-2017
# 272025                               None  Présent         None  2016-2017
# 272086                               None  Présent         None  2016-2017
# 272324                               None  Présent         None  2016-2017
# 272509                               None  Présent         None  2016-2017
# 272620                               None  Présent         None  2016-2017
# 272783                               None  Présent         None  2016-2017
# 272785                               None  Présent         None  2016-2017
# 272817                               None  Présent         None  2016-2017
# 273006                               None  Présent         None  2016-2017
# 273101                               None  Présent         None  2016-2017
# 273107            Foundations of Software  Présent         None  2016-2017
# 273118                               None  Présent         None  2016-2017
# 273156                               None  Présent         None  2016-2017
# 273163                               None  Présent         None  2016-2017
# 273182                               None  Présent         None  2016-2017
# 273251                               None  Présent         None  2016-2017
# 273563                               None  Présent         None  2016-2017
#
#                 exit semestre 1 semestre 2 semestre 3  semestre 4
# No Sciper
# 128911     2007-2008        NaN       True       True         NaN
# 129093     2007-2008        NaN       True       True         NaN
# 129326     2007-2008        NaN       True       True         NaN
# 138088     2007-2008       True        NaN        NaN         NaN
# 145546     2007-2008        NaN        NaN       True         NaN
# 145957     2007-2008        NaN        NaN       True         NaN
# 146330     2008-2009       True       True       True         NaN
# 146441     2007-2008        NaN        NaN       True         NaN
# 146742     2012-2013       True       True       True         NaN
# 146752     2007-2008        NaN        NaN       True         NaN
# 146929     2007-2008       True       True        NaN         NaN
# 147008     2012-2013       True       True       True         NaN
# 147358     2007-2008        NaN        NaN       True         NaN
# 147362     2007-2008        NaN        NaN       True         NaN
# 147366     2007-2008        NaN        NaN       True         NaN
# 147445     2007-2008        NaN        NaN       True         NaN
# 148900     2007-2008        NaN        NaN       True         NaN
# 152232     2008-2009       True       True       True         NaN
# 152238     2007-2008        NaN        NaN       True         NaN
# 153066     2009-2010       True       True       True         NaN
# 153324     2008-2009        NaN       True       True         NaN
# 153506     2007-2008        NaN        NaN       True         NaN
# 153640     2007-2008        NaN        NaN       True         NaN
# 153641     2007-2008        NaN        NaN       True         NaN
# 153642     2007-2008        NaN        NaN       True         NaN
# 153645     2007-2008        NaN        NaN       True         NaN
# 153664     2007-2008        NaN        NaN       True         NaN
# 153742     2007-2008        NaN       True       True         NaN
# 153746     2008-2009       True       True        NaN         NaN
# 153762     2009-2010       True       True       True         NaN
# ...              ...        ...        ...        ...         ...
# 268907     2016-2017       True        NaN        NaN         NaN
# 268910     2016-2017       True        NaN        NaN         NaN
# 269057     2016-2017       True        NaN        NaN         NaN
# 269096     2016-2017       True        NaN        NaN         NaN
# 269098     2016-2017       True        NaN        NaN         NaN
# 269369     2016-2017       True        NaN        NaN         NaN
# 269412     2016-2017       True        NaN        NaN         NaN
# 269423     2016-2017       True        NaN        NaN         NaN
# 269467     2016-2017       True        NaN        NaN         NaN
# 271189     2016-2017       True        NaN        NaN         NaN
# 271331     2016-2017       True        NaN        NaN         NaN
# 271711     2016-2017       True        NaN        NaN         NaN
# 271965     2016-2017       True        NaN        NaN         NaN
# 272025     2016-2017       True        NaN        NaN         NaN
# 272086     2016-2017       True        NaN        NaN         NaN
# 272324     2016-2017       True        NaN        NaN         NaN
# 272509     2016-2017       True        NaN        NaN         NaN
# 272620     2016-2017       True        NaN        NaN         NaN
# 272783     2016-2017       True        NaN        NaN         NaN
# 272785     2016-2017       True        NaN        NaN         NaN
# 272817     2016-2017       True        NaN        NaN         NaN
# 273006     2016-2017       True        NaN        NaN         NaN
# 273101     2016-2017       True        NaN        NaN         NaN
# 273107     2016-2017       True        NaN        NaN         NaN
# 273118     2016-2017       True        NaN        NaN         NaN
# 273156     2016-2017       True        NaN        NaN         NaN
# 273163     2016-2017       True        NaN        NaN         NaN
# 273182     2016-2017       True        NaN        NaN         NaN
# 273251     2016-2017       True        NaN        NaN         NaN
# 273563     2016-2017       True        NaN        NaN         NaN
#
# [977 rows x 19 columns]

# %%
df_final_master = df_final_master.drop(['Ecole Echange', 'Filičre opt.', 'Orientation Bachelor','Orientation Master', 'Statut', 'Type Echange', 'semestre 4' ],1)

# %%
init_dates = df_final_master[['enter', 'exit']].as_matrix()
durations = []
for i in init_dates:
    init = int(i[0].split('-')[0])
    final = int(i[1].split('-')[1])
    months = (final - init)*12 - 3
    durations.append(months)
sum(durations)/len(durations)
# Out:
# 19.047082906857728

# %%
df_final_grouped = df_final_master.drop(['Mineur', 'No Sciper', 'Nom Prénom', 'enter','exit'],1)
df_final_grouped=df_final_grouped.groupby(['Spécialisation', 'Civilité']).count().sum(axis = 1)
display(df_final_grouped)
# Out:
# Spécialisation                  Civilité
# Biocomputing                    Madame        9
#                                 Monsieur     14
# Computer Engineering - SP       Madame       10
#                                 Monsieur     52
# Computer Science Theory         Monsieur      3
# Data Analytics                  Madame        3
#                                 Monsieur     15
# Foundations of Software         Madame       17
#                                 Monsieur    173
# Information Security - SP       Monsieur     23
# Internet Information Systems    Madame        3
# Internet computing              Madame       28
#                                 Monsieur    274
# Service science                 Madame        3
#                                 Monsieur     10
# Signals, Images and Interfaces  Madame       10
#                                 Monsieur     89
# Software Systems                Madame        3
#                                 Monsieur     49
# dtype: int64

# %%
pd.DataFrame(df_final_grouped).unstack().plot.bar(stacked=True,by='Spécialisation')

# %%
init = df_final_master["enter"].str.split('-')
final = df_final_master["exit"].str.split('-')
time = []
for i in range(len(init)):
    first_year = int(final[i][1])
    last_year = int(init[i][0])
    time.append( (first_year-last_year)*12-3)
df_final_master['Time at EPFL'] = time
df_final_n = df_final_master.drop(['enter','exit','No Sciper','Mineur', 'Civilité','Time at EPFL','Nom Prénom'],1)
df_final_n = df_final_n.groupby('Spécialisation').count().sum(axis=1)
df_final_f = df_final_master.groupby(by=['Spécialisation'])['Time at EPFL'].sum()/df_final_n

# %%
pd.DataFrame(df_final_f).plot.bar(stacked=True,by='Spécialisation')
